# %%
# !python src/train.py trainer.max_epochs=2
# Out:
# [2024-06-17 12:43:26,765][src.utils.utils][INFO] - [rank: 0] Enforcing tags! <cfg.extras.enforce_tags=True>
# [2024-06-17 12:43:26,769][src.utils.utils][INFO] - [rank: 0] Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── data
# │   └── _target_: src.data.flip_rot_mnist_pair_datamodule.FlipRotMNISTPairModule
# │       data_dir: /local/scratch/a/lim316/research/vaub-gp-pl-hydra/data/
# │       batch_size: 1024
# │       num_workers: 16
# │       pin_memory: false
# │       rot_angle: 0
# │
# ├── model
# │   └── _target_: src.models.vaub_gp_module.VAUBGPModule
# │       optimizer_vae_1:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.002
# │         weight_decay: 0.0
# │       optimizer_vae_2:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.002
# │         weight_decay: 0.0
# │       optimizer_score:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# ...

# %%
# !ls -al
# Out:
# total 122660
# drwxr-sr-x 10 lim316 inouyegp      4096 Jun 17 11:59 .
# drwxr-sr-x 12 lim316 inouyegp       312 Jun 16 13:32 ..
# -rw-r--r--  1 lim316 inouyegp       346 Jun 16 13:33 .env.example
# drwxr-sr-x  8 lim316 inouyegp       237 Jun 16 22:12 .git
# drwxr-sr-x  3 lim316 inouyegp       147 Jun 16 13:33 .github
# -rw-r--r--  1 lim316 inouyegp      2094 Jun 16 13:33 .gitignore
# drwxr-sr-x  2 lim316 inouyegp       192 Jun 17 11:57 .ipynb_checkpoints
# -rw-r--r--  1 lim316 inouyegp      3655 Jun 16 13:33 .pre-commit-config.yaml
# -rw-r--r--  1 lim316 inouyegp        81 Jun 16 13:33 .project-root
# -rw-r--r--  1 lim316 inouyegp       759 Jun 16 13:33 Makefile
# -rw-r--r--  1 lim316 inouyegp     41778 Jun 16 13:33 README-template.md
# -rw-r--r--  1 lim316 inouyegp       125 Jun 16 13:33 README.md
# drwxr-sr-x 15 lim316 inouyegp       331 Jun 16 14:38 configs
# -rw-r--r--  1 lim316 inouyegp      1376 Jun 16 13:33 environment.yaml
# ...
